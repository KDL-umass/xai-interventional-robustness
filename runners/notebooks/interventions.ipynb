# %%
# %cd ../..
# Out:
# /home/echo/xai-interventional-robustness

# %%
from envs.interventions.space_invaders_interventions import *
import matplotlib.pyplot as plt

# %%
envs = get_all_interventions(False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f618ce503aa1> in <module>
# ----> 1 envs = get_all_interventions(False)
#
# NameError: name 'get_all_interventions' is not defined

# %%
envs = get_all_interventions(False)
fig = plt.figure()
for env in envs:
    for t in range(200):
        env.toybox.apply_ale_action(0)
    rgb = env.toybox.get_rgb_frame()
    plt.imshow(rgb, alpha=1/len(envs))
# Out:
# Returning 41 intervened environments.

# %%
rgb = envs[-1].toybox.get_rgb_frame()
plt.imshow(rgb)
