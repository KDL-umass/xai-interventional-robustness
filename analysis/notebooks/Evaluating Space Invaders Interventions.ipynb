# %%
# %cd ../..
from analysis.plotting.performance import *
# Out:
# /home

# %% [markdown]
# # Comparing Model Performance on Space Invaders
#
# ## Random vs DDT vs CNN

# %%
plot_vanilla_comparison(lives=1)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-c584b73d4f11> in <module>
# ----> 1 plot_vanilla_comparison(lives=1)
#
# ~/xai-interventional-robustness/analysis/plotting/performance.py in plot_vanilla_comparison(lives)
#      49     plt.subplot(2, 2, 1)
#      50
# ---> 51     random = np.loadtxt(f"storage/results/random_performance_vanilla_lives_{lives}.txt")
#      52     # ddt = np.loadtxt(f"storage/results/ddt_performance_vanilla_lives_{lives}.txt")
#      53     # cnn = np.loadtxt(f"storage/results/cnn_performance_vanilla_lives_{lives}.txt")
#
# ~/miniconda3/envs/xai/lib/python3.9/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     959             fname = os_fspath(fname)
#     960         if _is_string_like(fname):
# --> 961             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     962             fencoding = getattr(fh, 'encoding', 'latin1')
#     963             fh = iter(fh)
#
# ~/miniconda3/envs/xai/lib/python3.9/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     193
#     194     ds = DataSource(destpath)
# --> 195     return ds.open(path, mode, encoding=encoding, newline=newline)
#     196
#     197
#
# ~/miniconda3/envs/xai/lib/python3.9/site-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     533                                       encoding=encoding, newline=newline)
#     534         else:
# --> 535             raise IOError("%s not found." % path)
#     536
#     537
#
# OSError: storage/results/random_performance_vanilla_lives_1.txt not found.

# %%
# %%latex
# \newpage
# Out:
# \newpage

# %% [markdown]
# # Comparing Performance Under Intervention
#
# ## DDT

# %%
plot_dist("ddt_performance_lives_1", "ddt_performance_vanilla_lives_1", "DDT")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-53c57700a177> in <module>
# ----> 1 plot_dist("ddt_performance_lives_1", "ddt_performance_vanilla_lives_1", "DDT")
#
# ~/xai/camel3/Interpretable_DDTS-dev/interpretable_ddts/interventions/plotting.py in plot_dist(intervention_name, vanilla_name, agent_name)
#      18
#      19     maxscore = int(np.amax(ddt.ravel())) + 50
# ---> 20
#      21     plt.subplot(1, 2, 1)
#      22     plt.hist(ddt.ravel(), bins=range(0, maxscore, binwidth))
#
# IndexError: tuple index out of range

# %% [markdown]
# ## CNN

# %%
plot_dist("cnn_performance_lives_1", "cnn_performance_vanilla_lives_1", "CNN")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-a317edca07e8> in <module>
# ----> 1 plot_dist("cnn_performance_lives_1", "cnn_performance_vanilla_lives_1", "CNN")
#
# ~/xai/camel3/Interpretable_DDTS-dev/interpretable_ddts/interventions/plotting.py in plot_dist(intervention_name, vanilla_name, agent_name)
#      18
#      19     maxscore = int(np.amax(ddt.ravel())) + 50
# ---> 20
#      21     plt.subplot(1, 2, 1)
#      22     plt.hist(ddt.ravel(), bins=range(0, maxscore, binwidth))
#
# IndexError: tuple index out of range

# %%
# %%latex
# \newpage
# Out:
# \newpage

# %% [markdown]
# ## Random

# %%
plot_dist("random_performance_lives_1", "random_performance_vanilla_lives_1", "Random")
# Out:
# Ttest_indResult(statistic=1.739741461918305, pvalue=0.08284244231582631)
